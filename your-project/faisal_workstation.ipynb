# %%
import pandas as pd
import numpy as np
import re

# %%
accidents = pd.read_csv('../datasets/1.-Transportation/accidents-2017.csv')

# %%
# The Copy Cell
accidents_1 = accidents.copy() # Cleaned spaces at the end of string for column "Streets"

# %%
accidents_2 = accidents_1.copy() #

# %%
accidents.head(3)
# Out:
#                 Id District Name Neighborhood Name  \
# 0  2017S008429           Unknown           Unknown
# 1  2017S007316           Unknown           Unknown
# 2  2017S010210           Unknown           Unknown
#
#                                               Street Weekday      Month  Day  \
# 0  Número 27                                     ...  Friday    October   13
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...  Friday  September    1
# 2  Litoral (Besòs)                               ...  Friday   December    8
#
#    Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0     8         Morning              2                 0        2
# 1    13         Morning              2                 0        2
# 2    21       Afternoon              5                 0        5
#
#    Vehicles involved  Longitude   Latitude
# 0                  2   2.125624  41.340045
# 1                  2   2.120452  41.339426
# 2                  2   2.167356  41.360885

# %%
# After looking at the df, all data-types shown below make sence..
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10339 entries, 0 to 10338
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 10339 non-null  object
#  1   District Name      10339 non-null  object
#  2   Neighborhood Name  10339 non-null  object
#  3   Street             10339 non-null  object
#  4   Weekday            10339 non-null  object
#  5   Month              10339 non-null  object
#  6   Day                10339 non-null  int64
#  7   Hour               10339 non-null  int64
#  8   Part of the day    10339 non-null  object
#  9   Mild injuries      10339 non-null  int64
#  10  Serious injuries   10339 non-null  int64
#  11  Victims            10339 non-null  int64
#  12  Vehicles involved  10339 non-null  int64
#  13  Longitude          10339 non-null  float64
#  14  Latitude           10339 non-null  float64
# dtypes: float64(2), int64(6), object(7)
# ...

# %%
# We found and deleted 4 duplicates using this function. Previous df had 10339 entires where the one below has 10335
accidents.drop_duplicates()
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
accidents["District Name"].unique()
# Out:
# array(['Unknown', 'Sant Martí', 'Ciutat Vella', 'Eixample',
#        'Sants-Montjuïc', 'Les Corts', 'Sarrià-Sant Gervasi', 'Gràcia',
#        'Horta-Guinardó', 'Nou Barris', 'Sant Andreu'], dtype=object)

# %%
accidents["Neighborhood Name"].unique()
# Out:
# array(['Unknown', "el Camp de l'Arpa del Clot", 'el Clot',
#        'Sant Martí de Provençals', 'la Verneda i la Pau',
#        'el Besòs i el Maresme', 'Provençals del Poblenou', 'el Poblenou',
#        'Diagonal Mar i el Front Marítim del Poblenou',
#        'el Parc i la Llacuna del Poblenou', 'el Raval',
#        'la Vila Olímpica del Poblenou', 'el Barri Gòtic',
#        'Sant Pere, Santa Caterina i la Ribera', 'la Barceloneta',
#        'Sant Antoni', "la Nova Esquerra de l'Eixample",
#        'la Sagrada Família', "la Dreta de l'Eixample",
#        "l'Antiga Esquerra de l'Eixample", 'el Fort Pienc', 'el Poble-sec',
#        'la Marina del Prat Vermell', 'la Marina de Port', 'la Bordeta',
#        'Hostafrancs', 'la Font de la Guatlla', 'Sants', 'Sants - Badal',
#        'les Corts', 'la Maternitat i Sant Ramon', 'Pedralbes',
#        'Sant Gervasi - Galvany', 'Sarrià', 'Sant Gervasi - la Bonanova',
#        'les Tres Torres', 'el Putxet i el Farró',
# ...

# %%
#1 DONE - Street names have extra spaces 
#2 Delete street k + " /"
#3 All Caps entries should be fixed
#4 Same street in intersection should be fixed i.e (Gracia/Gracia should be Gracia)
#5 Litoral (dalt Besos) > (boats)
#last Intersection of same streets should be standardized i.e. (x/y and y/x should both be x/y)


streets = accidents["Street"].unique().tolist()
print(streets)
# Out:
# ['Número 27                                         ', 'Número 3 Zona Franca / Número 50 Zona Franca      ', 'Litoral (Besòs)                                   ', 'Número 3 Zona Franca                              ', 'Las Navas de Tolosa                               ', 'Indústria / Trinxant                              ', 'Trinxant / Indústria                              ', 'Indústria                                         ', 'Maragall                                          ', 'ST ANTONI M CLARET / Pg Maragall                  ', 'Sant Antoni Maria Claret / Guinardó               ', 'Sant Antoni Maria Claret                          ', 'Còrsega / Còrsega                                 ', 'CÒRSEGA / Dos de Maig                             ', 'Rosselló / Independència                          ', 'VALÈNCIA                                          ', 'València                                          ', 'València / Independència                          ', 'ARAGÓ / Corunya         
# ...

# %%
# Alles jut
accidents["Weekday"].unique()
accidents["Month"].unique()
accidents["Day"].unique()
accidents["Hour"].unique()
accidents["Part of the day"].unique()
accidents["Mild injuries"].unique()
accidents["Serious injuries"].unique()
accidents["Victims"].unique()
accidents["Vehicles involved"].unique()
# Out:
# array([ 2,  3,  1,  4,  5,  6, 13,  8,  9,  7, 10,  0, 11, 14])

# %%
street_series = accidents["Street"]

# %%
street_series = street_series.str.rstrip(to_strip = " ")

# %%
street_series
# Out:
# 0                                           Número 27
# 1        Número 3 Zona Franca / Número 50 Zona Franca
# 2                                     Litoral (Besòs)
# 3                                Número 3 Zona Franca
# 4                                 Las Navas de Tolosa
#                              ...
# 10334                             Litoral (Llobregat)
# 10335                                    PL MONTERREY
# 10336                             Litoral (Llobregat)
# 10337                                 Litoral (Besòs)
# 10338                               CIUTAT D'ASUNCIÓN
# Name: Street, Length: 10339, dtype: object

# %%
# Cleaned spaces at the end of string for column "Streets" > It works, we are happy
accidents_1["Street"] = street_series
accidents_1
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                              Street    Weekday      Month  \
# 0                                         Número 27     Friday    October
# ...

# %%
accidents_2.value_counts(["Neighborhood Name"])
# Out:
# Neighborhood Name
# la Dreta de l'Eixample             1167
# l'Antiga Esquerra de l'Eixample     588
# la Nova Esquerra de l'Eixample      387
# Sant Gervasi - Galvany              385
# la Sagrada Família                  377
#                                    ...
# Can Baró                             15
# Ciutat Meridiana                     11
# Vallbona                              8
# Can Peguera                           8
# Torre Baró                            7
# Length: 74, dtype: int64

# %%
neighborhoods = accidents_2["Neighborhood Name"].unique().tolist()
neighborhoods = [i.lower() for i in Neighborhoods]

neighborhoods
# Out:
# ['unknown',
#  "el camp de l'arpa del clot",
#  'el clot',
#  'sant martí de provençals',
#  'la verneda i la pau',
#  'el besòs i el maresme',
#  'provençals del poblenou',
#  'el poblenou',
#  'diagonal mar i el front marítim del poblenou',
#  'el parc i la llacuna del poblenou',
#  'el raval',
#  'la vila olímpica del poblenou',
#  'el barri gòtic',
#  'sant pere, santa caterina i la ribera',
#  'la barceloneta',
#  'sant antoni',
#  "la nova esquerra de l'eixample",
#  'la sagrada família',
#  "la dreta de l'eixample",
#  "l'antiga esquerra de l'eixample",
#  'el fort pienc',
#  'el poble-sec',
#  'la marina del prat vermell',
#  'la marina de port',
#  'la bordeta',
#  'hostafrancs',
#  'la font de la guatlla',
#  'sants',
#  'sants - badal',
#  'les corts',
#  'la maternitat i sant ramon',
#  'pedralbes',
#  'sant gervasi - galvany',
#  'sarrià',
#  'sant gervasi - la bonanova',
#  'les tres torres',
#  'el putxet i el farró',
#  'vallvidrera, el tibidabo i les planes',
# ...

# %%
hoods_df = pd.DataFrame(neighborhoods)

# %%
hoods_df
# Out:
#                              0
# 0                      unknown
# 1   el camp de l'arpa del clot
# 2                      el clot
# 3     sant martí de provençals
# 4          la verneda i la pau
# ..                         ...
# 69                 sant andreu
# 70                       navas
# 71           la trinitat vella
# 72               baró de viver
# 73               el bon pastor
#
# [74 rows x 1 columns]

# %%
hoods_df.drop_duplicates()
# Out:
#                              0
# 0                      unknown
# 1   el camp de l'arpa del clot
# 2                      el clot
# 3     sant martí de provençals
# 4          la verneda i la pau
# ..                         ...
# 69                 sant andreu
# 70                       navas
# 71           la trinitat vella
# 72               baró de viver
# 73               el bon pastor
#
# [74 rows x 1 columns]

# %%
hoods_df.describe()
# Out:
#             0
# count      74
# unique     74
# top     navas
# freq        1

# %%
# To run at the end
# Split Street intersections into Street 1 and Street 2
# accidents_2[['Street_1', 'Street_2']] = accidents_2['Street'].str.split(' / ', 1, expand=True)
